# %%
import pandas as pd

df = pd.read_csv('train_set_x.csv')
df
# Out:
#             Id                                               Text
# 0            0  Des mensonges Pas vraiment non cest juste que ...
# 1            1   Il faut dire au revoir à tout les plats préparés
# 2            2  Un très bon restaurant entre Tréguier et Lanni...
# 3            3  Bonjour Pour votre voyage soyons pratique Votr...
# 4            4  Selon moi un manque dargent Le chirurgien fait...
# 5            5  jetzt wirds aber wirklich erdig heute stell ic...
# 6            6  Je veux dire tu viens de sortir avec mon meilleur
# 7            7                                      126220 auf pc
# 8            8  Yo te pregunto que preferis las apps de andriod o
# 9            9    Je vous en prie Stephanie En fait javais du mal
# 10          10                                                Non
# 11          11        jaurais tellement aimé avoir une arme à feu
# 12          12                              Le capitaine Fluellen
# ...

# %%
df2 = pd.read_csv('train_set_y.csv')
df2
df
# Out:
#             Id                                               Text
# 0            0  Des mensonges Pas vraiment non cest juste que ...
# 1            1   Il faut dire au revoir à tout les plats préparés
# 2            2  Un très bon restaurant entre Tréguier et Lanni...
# 3            3  Bonjour Pour votre voyage soyons pratique Votr...
# 4            4  Selon moi un manque dargent Le chirurgien fait...
# 5            5  jetzt wirds aber wirklich erdig heute stell ic...
# 6            6  Je veux dire tu viens de sortir avec mon meilleur
# 7            7                                      126220 auf pc
# 8            8  Yo te pregunto que preferis las apps de andriod o
# 9            9    Je vous en prie Stephanie En fait javais du mal
# 10          10                                                Non
# 11          11        jaurais tellement aimé avoir une arme à feu
# 12          12                              Le capitaine Fluellen
# ...

# %%
df['Label'] = df2['Category']
df
# Out:
#             Id                                               Text  Label
# 0            0  Des mensonges Pas vraiment non cest juste que ...      1
# 1            1   Il faut dire au revoir à tout les plats préparés      1
# 2            2  Un très bon restaurant entre Tréguier et Lanni...      1
# 3            3  Bonjour Pour votre voyage soyons pratique Votr...      1
# 4            4  Selon moi un manque dargent Le chirurgien fait...      1
# 5            5  jetzt wirds aber wirklich erdig heute stell ic...      3
# 6            6  Je veux dire tu viens de sortir avec mon meilleur      1
# 7            7                                      126220 auf pc      3
# 8            8  Yo te pregunto que preferis las apps de andriod o      2
# 9            9    Je vous en prie Stephanie En fait javais du mal      1
# 10          10                                                Non      1
# 11          11        jaurais tellement aimé avoir une arme à feu      1
# ...

# %%
Label = []
for Labels, df_Label in df.groupby('Label'):
    Label.append(df_Label)
df0 = Label[0]
df1 = Label[1]
df2 = Label[2]
df3 = Label[3]
df4 = Label[4]

# %%
# Out:
#             Id                                               Text  Label
# 17          17                         Ty Suza ale dlaczego z nim      4
# 19          19  Niech nie przychodzi Zawsze przynosi tylko złe...      4
# 28          28                Możni książęta Gloster i Buckingham      4
# 84          84                          Lucjanie przecież miałeś…      4
# 93          93                                       Jak w wojsku      4
# 116        116  Świetnie Więc Pan D ma kochankę… powiedzmy Pan...      4
# 130        130                    Zabieram cię na próbę generalną      4
# 216        216  Tak tak mogę dodać tylko najsuchszy botaniczny...      4
# 241        241    Tak Ale oni mają siłę potęgę pieniądze a my Nam      4
# 242        242  Jeden z pociskiem drugi ślepy Ślepy się nie liczy      4
# 255        255           Przyjmijcie więc z spokojem nasz podarek      4
# 317        317                           Tu cały sęk miły kuzynie      4
# ...

# %%
Label = []
for Labels in df.groupby('Label'):
    Label.append(Labels)
Label
# Out:
# [(0,             Id                                               Text  Label
#   29          29     Počkaj kúsok ešte kojaaž potom sa spustí vojna      0
#   35          35                   Od roka jedia nase deti to co my      0
#   57          57                                    ďakujem za radu      0
#   60          60  Iste veď je dospelá a svojprávna A ja poznám veľa      0
#   100        100                                           ok vdaka      0
#   131        131  Co si myslite o tejto skole ma perspektívu to ist      0
#   139        139                     Prečo zakladáš duplicitné témy      0
#   150        150              Ake mate skusenosti s touto doktorkou      0
#   155        155  Ja som mala diagnostikovanu panicku poruchukym...      0
#   165        165  dakujem uz to mam aj potvrdene od lekarky taky...      0
#   168        168                 ahoj zail ja mam taky isti problem      0
# ...
